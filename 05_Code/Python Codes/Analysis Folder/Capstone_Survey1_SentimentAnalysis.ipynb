# %%
from google.colab import auth
auth.authenticate_user()

# %%
import numpy as np
import pandas as pd
import pandas_gbq

# %%
Feedback_data = pandas_gbq.read_gbq(f'SELECT * FROM `surveyproject-378222.Capstone_Project.Feedback`',project_id='surveyproject-378222', dialect='standard')
# Out:
# Downloading: 100%|██████████|

# %%
Feedback_data
# Out:
#       ID                                           Feedback
# 0    317                                                 No
# 1    116                                                 No
# 2    111                                                 na
# 3    267                                                 no
# 4    263                                                sad
# ..   ...                                                ...
# 345   92  I am very disappointed with this program. The ...
# 346  196  I came to St. Clair college to gain experience...
# 347  114  I think there is a gap between the college off...
# 348  230  College should think of having 3 days per week...
# 349   84  Class schedule should be more student centric,...
#
# [350 rows x 2 columns]

# %% [markdown]
# #1) Normalization

# %%
import re
fdk = Feedback_data
def  clean_text(df, text_field, new_text_field_name):
    df[new_text_field_name] = df[text_field].str.lower()
    df[new_text_field_name] = df[new_text_field_name].str.replace(r"@[A-Za-z0-9]+", "")  # remove Twitter usernames
    df[new_text_field_name] = df[new_text_field_name].str.replace(r"[^0-9A-Za-z \t]", "")  # remove non-alphanumeric characters
    df[new_text_field_name] = df[new_text_field_name].str.replace(r"http\S+", "")  # remove URLs
    df[new_text_field_name] = df[new_text_field_name].str.replace(r"^rt", "")  # remove retweet indicator
    df[new_text_field_name] = df[new_text_field_name].str.strip()  # remove leading/trailing whitespace 
    # remove numbers
    df[new_text_field_name] = df[new_text_field_name].str.replace('\d+', '') 
    return df
data_clean = clean_text(fdk , 'Feedback', 'text_clean')
data_clean.head()
# Out:
# <ipython-input-5-09e31bd14f19>:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   df[new_text_field_name] = df[new_text_field_name].str.replace(r"@[A-Za-z0-9]+", "")  # remove Twitter usernames
# <ipython-input-5-09e31bd14f19>:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   df[new_text_field_name] = df[new_text_field_name].str.replace(r"[^0-9A-Za-z \t]", "")  # remove non-alphanumeric characters
# <ipython-input-5-09e31bd14f19>:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df[new_text_field_name] = df[new_text_field_name].str.replace(r"http\S+", "")  # remove URLs
# <ipython-input-5-09e31bd14f19>:8: FutureWarning: The default value of regex will change from True to False in a future version.
#   df[new_text_field_name] = df[new_text_field_name].str.replace(r"^rt", "")  # remove retweet indicator
# <ipython-input-5-09e31bd14f19>:11: FutureWarning: The default value of regex will change from True to False in a future version.
#   df[new_text_field_name] = df[new_text_field_name].str.replace('\d+', '')
#     ID Feedback text_clean
# 0  317       No         no
# 1  116       No         no
# 2  111       na         na
# 3  267       no         no
# 4  263      sad        sad

# %%
fdk
# Out:
#       ID                                           Feedback  \
# 0    317                                                 No
# 1    116                                                 No
# 2    111                                                 na
# 3    267                                                 no
# 4    263                                                sad
# ..   ...                                                ...
# 345   92  I am very disappointed with this program. The ...
# 346  196  I came to St. Clair college to gain experience...
# 347  114  I think there is a gap between the college off...
# 348  230  College should think of having 3 days per week...
# 349   84  Class schedule should be more student centric,...
#
#                                             text_clean
# 0                                                   no
# 1                                                   no
# 2                                                   na
# 3                                                   no
# 4                                                  sad
# ..                                                 ...
# 345  i am very disappointed with this program the p...
# 346  i came to st clair college to gain experience ...
# 347  i think there is a gap between the college off...
# 348  college should think of having  days per week ...
# 349  class schedule should be more student centric ...
#
# [350 rows x 3 columns]

# %% [markdown]
# #2) Stop words

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
data_clean['text_clean'] = data_clean['text_clean'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop_words)]) if x is not None else '')
data_clean.head()

#data_clean['text_clean'] = data_clean['text_clean'].apply(lambda x: ' '.join([word for word in x.split() if word.lower() not in stop_words]))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
#     ID Feedback text_clean
# 0  317       No
# 1  116       No
# 2  111       na         na
# 3  267       no
# 4  263      sad        sad

# %%
fdk
# Out:
#       ID                                           Feedback  \
# 0    317                                                 No
# 1    116                                                 No
# 2    111                                                 na
# 3    267                                                 no
# 4    263                                                sad
# ..   ...                                                ...
# 345   92  I am very disappointed with this program. The ...
# 346  196  I came to St. Clair college to gain experience...
# 347  114  I think there is a gap between the college off...
# 348  230  College should think of having 3 days per week...
# 349   84  Class schedule should be more student centric,...
#
#                                             text_clean
# 0
# 1
# 2                                                   na
# 3
# 4                                                  sad
# ..                                                 ...
# 345  disappointed program professors seem expect st...
# 346  came st clair college gain experience meeting ...
# 347  think gap college offering services students a...
# 348  college think days per week also college follo...
# 349  class schedule student centric also work livin...
#
# [350 rows x 3 columns]

# %% [markdown]
# #3) Tokenization

# %%
import nltk 
nltk.download('punkt')
from nltk.tokenize import sent_tokenize, word_tokenize
data_clean['text_tokens'] = data_clean['text_clean'].apply(lambda x: word_tokenize(x))
data_clean.head()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
#     ID Feedback text_clean text_tokens
# 0  317       No                     []
# 1  116       No                     []
# 2  111       na         na        [na]
# 3  267       no                     []
# 4  263      sad        sad       [sad]

# %%
fdk
# Out:
#       ID                                           Feedback  \
# 0    317                                                 No
# 1    116                                                 No
# 2    111                                                 na
# 3    267                                                 no
# 4    263                                                sad
# ..   ...                                                ...
# 345   92  I am very disappointed with this program. The ...
# 346  196  I came to St. Clair college to gain experience...
# 347  114  I think there is a gap between the college off...
# 348  230  College should think of having 3 days per week...
# 349   84  Class schedule should be more student centric,...
#
#                                             text_clean  \
# 0
# 1
# 2                                                   na
# 3
# 4                                                  sad
# ..                                                 ...
# 345  disappointed program professors seem expect st...
# 346  came st clair college gain experience meeting ...
# 347  think gap college offering services students a...
# 348  college think days per week also college follo...
# 349  class schedule student centric also work livin...
#
#                                            text_tokens
# 0                                                   []
# 1                                                   []
# 2                                                 [na]
# 3                                                   []
# 4                                                [sad]
# ..                                                 ...
# 345  [disappointed, program, professors, seem, expe...
# 346  [came, st, clair, college, gain, experience, m...
# 347  [think, gap, college, offering, services, stud...
# 348  [college, think, days, per, week, also, colleg...
# 349  [class, schedule, student, centric, also, work...
#
# [350 rows x 4 columns]

# %% [markdown]
# #4) Stemming

# %%
from nltk.stem import PorterStemmer 
def word_stemmer(Feedback):
    stem_text = [PorterStemmer().stem(i) for i in Feedback]
    return stem_text
data_clean['text_tokens_stem'] = data_clean['text_tokens'].apply(lambda x: word_stemmer(x))
data_clean.head()
# Out:
#     ID Feedback text_clean text_tokens text_tokens_stem
# 0  317       No                     []               []
# 1  116       No                     []               []
# 2  111       na         na        [na]             [na]
# 3  267       no                     []               []
# 4  263      sad        sad       [sad]            [sad]

# %%
fdk
# Out:
#       ID                                           Feedback  \
# 0    317                                                 No
# 1    116                                                 No
# 2    111                                                 na
# 3    267                                                 no
# 4    263                                                sad
# ..   ...                                                ...
# 345   92  I am very disappointed with this program. The ...
# 346  196  I came to St. Clair college to gain experience...
# 347  114  I think there is a gap between the college off...
# 348  230  College should think of having 3 days per week...
# 349   84  Class schedule should be more student centric,...
#
#                                             text_clean  \
# 0
# 1
# 2                                                   na
# 3
# 4                                                  sad
# ..                                                 ...
# 345  disappointed program professors seem expect st...
# 346  came st clair college gain experience meeting ...
# 347  think gap college offering services students a...
# 348  college think days per week also college follo...
# 349  class schedule student centric also work livin...
#
#                                            text_tokens  \
# 0                                                   []
# 1                                                   []
# 2                                                 [na]
# 3                                                   []
# 4                                                [sad]
# ..                                                 ...
# 345  [disappointed, program, professors, seem, expe...
# 346  [came, st, clair, college, gain, experience, m...
# 347  [think, gap, college, offering, services, stud...
# 348  [college, think, days, per, week, also, colleg...
# 349  [class, schedule, student, centric, also, work...
#
#                                       text_tokens_stem
# 0                                                   []
# 1                                                   []
# 2                                                 [na]
# 3                                                   []
# 4                                                [sad]
# ..                                                 ...
# 345  [disappoint, program, professor, seem, expect,...
# 346  [came, st, clair, colleg, gain, experi, meet, ...
# 347  [think, gap, colleg, offer, servic, student, a...
# 348  [colleg, think, day, per, week, also, colleg, ...
# 349  [class, schedul, student, centric, also, work,...
#
# [350 rows x 5 columns]

# %% [markdown]
# #5) Lemmatization

# %%
import nltk
nltk.download('omw-1.4')
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
def word_lemmatizer(Feedback):
    lem_text = [WordNetLemmatizer().lemmatize(i) for i in Feedback]
    return lem_text
data_clean['text_tokens_lemma'] = data_clean['text_tokens'].apply(lambda x: word_lemmatizer(x))
data_clean.head()
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data] Downloading package wordnet to /root/nltk_data...
#     ID Feedback text_clean text_tokens text_tokens_stem text_tokens_lemma
# 0  317       No                     []               []                []
# 1  116       No                     []               []                []
# 2  111       na         na        [na]             [na]              [na]
# 3  267       no                     []               []                []
# 4  263      sad        sad       [sad]            [sad]             [sad]

# %%
fdk
# Out:
#       ID                                           Feedback  \
# 0    317                                                 No
# 1    116                                                 No
# 2    111                                                 na
# 3    267                                                 no
# 4    263                                                sad
# ..   ...                                                ...
# 345   92  I am very disappointed with this program. The ...
# 346  196  I came to St. Clair college to gain experience...
# 347  114  I think there is a gap between the college off...
# 348  230  College should think of having 3 days per week...
# 349   84  Class schedule should be more student centric,...
#
#                                             text_clean  \
# 0
# 1
# 2                                                   na
# 3
# 4                                                  sad
# ..                                                 ...
# 345  disappointed program professors seem expect st...
# 346  came st clair college gain experience meeting ...
# 347  think gap college offering services students a...
# 348  college think days per week also college follo...
# 349  class schedule student centric also work livin...
#
#                                            text_tokens  \
# 0                                                   []
# 1                                                   []
# 2                                                 [na]
# 3                                                   []
# 4                                                [sad]
# ..                                                 ...
# 345  [disappointed, program, professors, seem, expe...
# 346  [came, st, clair, college, gain, experience, m...
# 347  [think, gap, college, offering, services, stud...
# 348  [college, think, days, per, week, also, colleg...
# 349  [class, schedule, student, centric, also, work...
#
#                                       text_tokens_stem  \
# 0                                                   []
# 1                                                   []
# 2                                                 [na]
# 3                                                   []
# 4                                                [sad]
# ..                                                 ...
# 345  [disappoint, program, professor, seem, expect,...
# 346  [came, st, clair, colleg, gain, experi, meet, ...
# 347  [think, gap, colleg, offer, servic, student, a...
# 348  [colleg, think, day, per, week, also, colleg, ...
# 349  [class, schedul, student, centric, also, work,...
#
#                                      text_tokens_lemma
# 0                                                   []
# 1                                                   []
# 2                                                 [na]
# 3                                                   []
# 4                                                [sad]
# ..                                                 ...
# 345  [disappointed, program, professor, seem, expec...
# 346  [came, st, clair, college, gain, experience, m...
# 347  [think, gap, college, offering, service, stude...
# 348  [college, think, day, per, week, also, college...
# 349  [class, schedule, student, centric, also, work...
#
# [350 rows x 6 columns]

# %%
lemmatized_text=fdk['text_tokens_lemma']

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %% [markdown]
# ## **Sentiment Analysis**

# %%
lemmatized_text
# Out:
# 0                                                     []
# 1                                                     []
# 2                                                   [na]
# 3                                                     []
# 4                                                  [sad]
#                              ...
# 345    [disappointed, program, professor, seem, expec...
# 346    [came, st, clair, college, gain, experience, m...
# 347    [think, gap, college, offering, service, stude...
# 348    [college, think, day, per, week, also, college...
# 349    [class, schedule, student, centric, also, work...
# Name: text_tokens_lemma, Length: 350, dtype: object

# %%
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
import pandas as pd

# Instantiate the SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()

# Define a function to apply the sentiment analyzer to each row of text
def get_sentiment_score(text):
    text_str = ' '.join(text)
    return sia.polarity_scores(text_str)['compound']


# Drop the rows containing None values in the 'text_tokens_lemma' column
fdk = fdk.dropna(subset=['text_tokens_lemma'])

# Apply the function to the 'text_tokens_lemma' column and create a new column with the sentiment scores
fdk['sentiment_score'] = fdk['text_tokens_lemma'].apply(get_sentiment_score)

# Group the DataFrame by the unique identifier and calculate the mean sentiment score for each group
grouped = fdk.groupby('ID')['sentiment_score'].mean()

# Print the group-wise sentiment scores
for ID, score in grouped.items():
    if score > 0:
        print('The text with unique id {} has a positive sentiment score of {:.2f}.'.format(ID, score))
    elif score < 0:
        print('The text with unique id {} has a negative sentiment score of {:.2f}.'.format(ID, score))
    else:
        print('The text with unique id {} has a neutral sentiment score of {:.2f}.'.format(ID, score))
# Out:
# The text with unique id 1 has a negative sentiment score of -0.32.
# The text with unique id 2 has a neutral sentiment score of 0.00.
# The text with unique id 3 has a neutral sentiment score of 0.00.
# The text with unique id 4 has a neutral sentiment score of 0.00.
# The text with unique id 5 has a neutral sentiment score of 0.00.
# The text with unique id 6 has a neutral sentiment score of 0.00.
# The text with unique id 7 has a neutral sentiment score of 0.00.
# The text with unique id 8 has a neutral sentiment score of 0.00.
# The text with unique id 9 has a neutral sentiment score of 0.00.
# The text with unique id 10 has a positive sentiment score of 0.03.
# The text with unique id 11 has a neutral sentiment score of 0.00.
# The text with unique id 12 has a neutral sentiment score of 0.00.
# The text with unique id 13 has a negative sentiment score of -0.19.
# The text with unique id 14 has a neutral sentiment score of 0.00.
# The text with unique id 15 has a neutral sentiment score of 0.00.
# The text with unique id 16 has a neutral sentiment score of 0.00.
# The text with unique id 17 has a positive sentiment score of 0.34.
# The text with unique id 18 has a neutral sentiment score of 0.00.
# The text with unique id 19 has a neutral sentiment score of 0.00.
# The text with unique id 20 has a positive sentiment score of 0.42.
# The text with unique id 21 has a neutral sentiment score of 0.00.
# The text with unique id 22 has a neutral sentiment score of 0.00.
# The text with unique id 23 has a neutral sentiment score of 0.00.
# The text with unique id 24 has a positive sentiment score of 0.71.
# The text with unique id 25 has a positive sentiment score of 0.57.
# The text with unique id 26 has a neutral sentiment score of 0.00.
# The text with unique id 27 has a neutral sentiment score of 0.00.
# The text with unique id 28 has a neutral sentiment score of 0.00.
# The text with unique id 29 has a neutral sentiment score of 0.00.
# The text with unique id 30 has a neutral sentiment score of 0.00.
# The text with unique id 31 has a neutral sentiment score of 0.00.
# The text with unique id 32 has a neutral sentiment score of 0.00.
# The text with unique id 33 has a neutral sentiment score of 0.00.
# The text with unique id 34 has a neutral sentiment score of 0.00.
# The text with unique id 35 has a neutral sentiment score of 0.00.
# The text with unique id 36 has a neutral sentiment score of 0.00.
# The text with unique id 37 has a neutral sentiment score of 0.00.
# The text with unique id 38 has a positive sentiment score of 0.42.
# The text with unique id 39 has a neutral sentiment score of 0.00.
# The text with unique id 40 has a neutral sentiment score of 0.00.
# The text with unique id 41 has a neutral sentiment score of 0.00.
# The text with unique id 42 has a neutral sentiment score of 0.00.
# The text with unique id 43 has a neutral sentiment score of 0.00.
# The text with unique id 44 has a neutral sentiment score of 0.00.
# The text with unique id 45 has a positive sentiment score of 0.74.
# The text with unique id 46 has a neutral sentiment score of 0.00.
# The text with unique id 47 has a positive sentiment score of 0.46.
# The text with unique id 48 has a positive sentiment score of 0.62.
# The text with unique id 49 has a positive sentiment score of 0.42.
# The text with unique id 50 has a neutral sentiment score of 0.00.
# The text with unique id 51 has a neutral sentiment score of 0.00.
# The text with unique id 52 has a neutral sentiment score of 0.00.
# The text with unique id 53 has a neutral sentiment score of 0.00.
# The text with unique id 54 has a positive sentiment score of 0.23.
# The text with unique id 55 has a neutral sentiment score of 0.00.
# The text with unique id 56 has a positive sentiment score of 0.18.
# The text with unique id 57 has a negative sentiment score of -0.84.
# The text with unique id 58 has a positive sentiment score of 0.44.
# The text with unique id 59 has a neutral sentiment score of 0.00.
# The text with unique id 60 has a neutral sentiment score of 0.00.
# The text with unique id 61 has a neutral sentiment score of 0.00.
# The text with unique id 62 has a neutral sentiment score of 0.00.
# The text with unique id 63 has a neutral sentiment score of 0.00.
# The text with unique id 64 has a neutral sentiment score of 0.00.
# The text with unique id 65 has a neutral sentiment score of 0.00.
# The text with unique id 66 has a neutral sentiment score of 0.00.
# The text with unique id 67 has a neutral sentiment score of 0.00.
# The text with unique id 68 has a positive sentiment score of 0.71.
# The text with unique id 69 has a neutral sentiment score of 0.00.
# The text with unique id 70 has a neutral sentiment score of 0.00.
# The text with unique id 71 has a neutral sentiment score of 0.00.
# The text with unique id 72 has a positive sentiment score of 0.44.
# The text with unique id 73 has a neutral sentiment score of 0.00.
# The text with unique id 74 has a neutral sentiment score of 0.00.
# The text with unique id 75 has a neutral sentiment score of 0.00.
# The text with unique id 76 has a positive sentiment score of 0.32.
# The text with unique id 77 has a neutral sentiment score of 0.00.
# The text with unique id 78 has a neutral sentiment score of 0.00.
# The text with unique id 79 has a neutral sentiment score of 0.00.
# The text with unique id 80 has a positive sentiment score of 0.87.
# The text with unique id 81 has a neutral sentiment score of 0.00.
# The text with unique id 82 has a positive sentiment score of 0.44.
# The text with unique id 83 has a neutral sentiment score of 0.00.
# The text with unique id 84 has a neutral sentiment score of 0.00.
# The text with unique id 85 has a positive sentiment score of 0.95.
# The text with unique id 86 has a positive sentiment score of 0.05.
# The text with unique id 87 has a positive sentiment score of 0.05.
# The text with unique id 88 has a positive sentiment score of 0.74.
# The text with unique id 89 has a neutral sentiment score of 0.00.
# The text with unique id 90 has a neutral sentiment score of 0.00.
# The text with unique id 91 has a positive sentiment score of 0.32.
# The text with unique id 92 has a negative sentiment score of -0.46.
# The text with unique id 93 has a negative sentiment score of -0.46.
# The text with unique id 94 has a positive sentiment score of 0.89.
# The text with unique id 95 has a neutral sentiment score of 0.00.
# The text with unique id 96 has a positive sentiment score of 0.58.
# The text with unique id 97 has a neutral sentiment score of 0.00.
# The text with unique id 98 has a positive sentiment score of 0.25.
# The text with unique id 99 has a neutral sentiment score of 0.00.
# The text with unique id 100 has a positive sentiment score of 0.08.
# The text with unique id 101 has a neutral sentiment score of 0.00.
# The text with unique id 102 has a neutral sentiment score of 0.00.
# The text with unique id 103 has a neutral sentiment score of 0.00.
# The text with unique id 104 has a neutral sentiment score of 0.00.
# The text with unique id 105 has a neutral sentiment score of 0.00.
# The text with unique id 106 has a positive sentiment score of 0.89.
# The text with unique id 107 has a neutral sentiment score of 0.00.
# The text with unique id 108 has a neutral sentiment score of 0.00.
# The text with unique id 109 has a negative sentiment score of -0.18.
# The text with unique id 110 has a neutral sentiment score of 0.00.
# The text with unique id 111 has a neutral sentiment score of 0.00.
# The text with unique id 112 has a neutral sentiment score of 0.00.
# The text with unique id 113 has a neutral sentiment score of 0.00.
# The text with unique id 114 has a positive sentiment score of 0.40.
# The text with unique id 115 has a neutral sentiment score of 0.00.
# The text with unique id 116 has a neutral sentiment score of 0.00.
# The text with unique id 117 has a neutral sentiment score of 0.00.
# The text with unique id 118 has a neutral sentiment score of 0.00.
# The text with unique id 119 has a neutral sentiment score of 0.00.
# The text with unique id 120 has a neutral sentiment score of 0.00.
# The text with unique id 121 has a positive sentiment score of 0.13.
# The text with unique id 122 has a positive sentiment score of 0.27.
# The text with unique id 123 has a neutral sentiment score of 0.00.
# The text with unique id 124 has a neutral sentiment score of 0.00.
# The text with unique id 125 has a neutral sentiment score of 0.00.
# The text with unique id 126 has a neutral sentiment score of 0.00.
# The text with unique id 127 has a neutral sentiment score of 0.00.
# The text with unique id 128 has a neutral sentiment score of 0.00.
# The text with unique id 129 has a neutral sentiment score of 0.00.
# The text with unique id 130 has a neutral sentiment score of 0.00.
# The text with unique id 131 has a positive sentiment score of 0.32.
# The text with unique id 132 has a positive sentiment score of 0.61.
# The text with unique id 133 has a neutral sentiment score of 0.00.
# The text with unique id 134 has a positive sentiment score of 0.62.
# The text with unique id 135 has a neutral sentiment score of 0.00.
# The text with unique id 136 has a neutral sentiment score of 0.00.
# The text with unique id 137 has a neutral sentiment score of 0.00.
# The text with unique id 138 has a neutral sentiment score of 0.00.
# The text with unique id 139 has a neutral sentiment score of 0.00.
# The text with unique id 140 has a neutral sentiment score of 0.00.
# The text with unique id 141 has a positive sentiment score of 0.34.
# The text with unique id 142 has a neutral sentiment score of 0.00.
# The text with unique id 143 has a positive sentiment score of 0.71.
# The text with unique id 144 has a neutral sentiment score of 0.00.
# The text with unique id 145 has a negative sentiment score of -0.46.
# The text with unique id 146 has a neutral sentiment score of 0.00.
# The text with unique id 147 has a neutral sentiment score of 0.00.
# The text with unique id 148 has a positive sentiment score of 0.72.
# The text with unique id 149 has a neutral sentiment score of 0.00.
# The text with unique id 150 has a neutral sentiment score of 0.00.
# The text with unique id 151 has a neutral sentiment score of 0.00.
# The text with unique id 152 has a neutral sentiment score of 0.00.
# The text with unique id 153 has a neutral sentiment score of 0.00.
# The text with unique id 154 has a neutral sentiment score of 0.00.
# The text with unique id 155 has a neutral sentiment score of 0.00.
# The text with unique id 156 has a positive sentiment score of 0.84.
# The text with unique id 157 has a neutral sentiment score of 0.00.
# The text with unique id 158 has a positive sentiment score of 0.46.
# The text with unique id 159 has a neutral sentiment score of 0.00.
# The text with unique id 160 has a neutral sentiment score of 0.00.
# The text with unique id 161 has a neutral sentiment score of 0.00.
# The text with unique id 162 has a positive sentiment score of 0.44.
# The text with unique id 163 has a neutral sentiment score of 0.00.
# The text with unique id 164 has a neutral sentiment score of 0.00.
# The text with unique id 165 has a neutral sentiment score of 0.00.
# The text with unique id 166 has a neutral sentiment score of 0.00.
# The text with unique id 167 has a neutral sentiment score of 0.00.
# The text with unique id 168 has a negative sentiment score of -0.05.
# The text with unique id 169 has a negative sentiment score of -0.05.
# The text with unique id 170 has a neutral sentiment score of 0.00.
# The text with unique id 171 has a neutral sentiment score of 0.00.
# The text with unique id 172 has a neutral sentiment score of 0.00.
# The text with unique id 173 has a neutral sentiment score of 0.00.
# The text with unique id 174 has a neutral sentiment score of 0.00.
# The text with unique id 175 has a neutral sentiment score of 0.00.
# The text with unique id 176 has a neutral sentiment score of 0.00.
# The text with unique id 177 has a neutral sentiment score of 0.00.
# The text with unique id 178 has a neutral sentiment score of 0.00.
# The text with unique id 179 has a neutral sentiment score of 0.00.
# The text with unique id 180 has a negative sentiment score of -0.27.
# The text with unique id 181 has a positive sentiment score of 0.81.
# The text with unique id 182 has a negative sentiment score of -0.02.
# The text with unique id 183 has a neutral sentiment score of 0.00.
# The text with unique id 184 has a neutral sentiment score of 0.00.
# The text with unique id 185 has a neutral sentiment score of 0.00.
# The text with unique id 186 has a neutral sentiment score of 0.00.
# The text with unique id 187 has a neutral sentiment score of 0.00.
# The text with unique id 188 has a neutral sentiment score of 0.00.
# The text with unique id 189 has a neutral sentiment score of 0.00.
# The text with unique id 190 has a neutral sentiment score of 0.00.
# The text with unique id 191 has a negative sentiment score of -0.84.
# The text with unique id 192 has a neutral sentiment score of 0.00.
# The text with unique id 193 has a negative sentiment score of -0.24.
# The text with unique id 194 has a positive sentiment score of 0.44.
# The text with unique id 195 has a neutral sentiment score of 0.00.
# The text with unique id 196 has a positive sentiment score of 0.53.
# The text with unique id 197 has a neutral sentiment score of 0.00.
# The text with unique id 198 has a positive sentiment score of 0.27.
# The text with unique id 199 has a neutral sentiment score of 0.00.
# The text with unique id 200 has a positive sentiment score of 0.44.
# The text with unique id 201 has a neutral sentiment score of 0.00.
# The text with unique id 202 has a neutral sentiment score of 0.00.
# The text with unique id 203 has a neutral sentiment score of 0.00.
# The text with unique id 204 has a neutral sentiment score of 0.00.
# The text with unique id 205 has a positive sentiment score of 0.44.
# The text with unique id 206 has a neutral sentiment score of 0.00.
# The text with unique id 207 has a neutral sentiment score of 0.00.
# The text with unique id 208 has a neutral sentiment score of 0.00.
# The text with unique id 209 has a neutral sentiment score of 0.00.
# The text with unique id 210 has a neutral sentiment score of 0.00.
# The text with unique id 211 has a neutral sentiment score of 0.00.
# The text with unique id 212 has a neutral sentiment score of 0.00.
# The text with unique id 213 has a neutral sentiment score of 0.00.
# The text with unique id 214 has a positive sentiment score of 0.94.
# The text with unique id 215 has a neutral sentiment score of 0.00.
# The text with unique id 216 has a neutral sentiment score of 0.00.
# The text with unique id 217 has a neutral sentiment score of 0.00.
# The text with unique id 218 has a neutral sentiment score of 0.00.
# The text with unique id 219 has a neutral sentiment score of 0.00.
# The text with unique id 220 has a neutral sentiment score of 0.00.
# The text with unique id 221 has a positive sentiment score of 0.88.
# The text with unique id 222 has a positive sentiment score of 0.38.
# The text with unique id 223 has a neutral sentiment score of 0.00.
# The text with unique id 224 has a positive sentiment score of 0.44.
# The text with unique id 225 has a neutral sentiment score of 0.00.
# The text with unique id 226 has a neutral sentiment score of 0.00.
# The text with unique id 227 has a neutral sentiment score of 0.00.
# The text with unique id 228 has a neutral sentiment score of 0.00.
# The text with unique id 229 has a neutral sentiment score of 0.00.
# The text with unique id 230 has a neutral sentiment score of 0.00.
# The text with unique id 231 has a neutral sentiment score of 0.00.
# The text with unique id 232 has a neutral sentiment score of 0.00.
# The text with unique id 233 has a neutral sentiment score of 0.00.
# The text with unique id 234 has a neutral sentiment score of 0.00.
# The text with unique id 235 has a neutral sentiment score of 0.00.
# The text with unique id 236 has a neutral sentiment score of 0.00.
# The text with unique id 237 has a neutral sentiment score of 0.00.
# The text with unique id 238 has a neutral sentiment score of 0.00.
# The text with unique id 239 has a neutral sentiment score of 0.00.
# The text with unique id 240 has a positive sentiment score of 0.44.
# The text with unique id 242 has a negative sentiment score of -0.08.
# The text with unique id 243 has a neutral sentiment score of 0.00.
# The text with unique id 244 has a neutral sentiment score of 0.00.
# The text with unique id 245 has a neutral sentiment score of 0.00.
# The text with unique id 246 has a positive sentiment score of 0.08.
# The text with unique id 247 has a neutral sentiment score of 0.00.
# The text with unique id 248 has a neutral sentiment score of 0.00.
# The text with unique id 249 has a neutral sentiment score of 0.00.
# The text with unique id 250 has a neutral sentiment score of 0.00.
# The text with unique id 251 has a neutral sentiment score of 0.00.
# The text with unique id 252 has a positive sentiment score of 0.05.
# The text with unique id 253 has a neutral sentiment score of 0.00.
# The text with unique id 254 has a neutral sentiment score of 0.00.
# The text with unique id 255 has a neutral sentiment score of 0.00.
# The text with unique id 256 has a neutral sentiment score of 0.00.
# The text with unique id 257 has a positive sentiment score of 0.70.
# The text with unique id 258 has a positive sentiment score of 0.20.
# The text with unique id 259 has a positive sentiment score of 0.64.
# The text with unique id 260 has a neutral sentiment score of 0.00.
# The text with unique id 261 has a negative sentiment score of -0.60.
# The text with unique id 262 has a negative sentiment score of -0.48.
# The text with unique id 263 has a negative sentiment score of -0.48.
# The text with unique id 264 has a negative sentiment score of -0.42.
# The text with unique id 265 has a neutral sentiment score of 0.00.
# The text with unique id 266 has a neutral sentiment score of 0.00.
# The text with unique id 267 has a neutral sentiment score of 0.00.
# The text with unique id 268 has a neutral sentiment score of 0.00.
# The text with unique id 269 has a neutral sentiment score of 0.00.
# The text with unique id 270 has a neutral sentiment score of 0.00.
# The text with unique id 271 has a negative sentiment score of -0.60.
# The text with unique id 272 has a neutral sentiment score of 0.00.
# The text with unique id 273 has a positive sentiment score of 0.30.
# The text with unique id 274 has a neutral sentiment score of 0.00.
# The text with unique id 275 has a neutral sentiment score of 0.00.
# The text with unique id 276 has a neutral sentiment score of 0.00.
# The text with unique id 277 has a positive sentiment score of 0.44.
# The text with unique id 278 has a neutral sentiment score of 0.00.
# The text with unique id 279 has a negative sentiment score of -0.59.
# The text with unique id 280 has a positive sentiment score of 0.44.
# The text with unique id 281 has a neutral sentiment score of 0.00.
# The text with unique id 282 has a neutral sentiment score of 0.00.
# The text with unique id 283 has a neutral sentiment score of 0.00.
# The text with unique id 284 has a neutral sentiment score of 0.00.
# The text with unique id 285 has a neutral sentiment score of 0.00.
# The text with unique id 286 has a neutral sentiment score of 0.00.
# The text with unique id 287 has a positive sentiment score of 0.44.
# The text with unique id 288 has a neutral sentiment score of 0.00.
# The text with unique id 289 has a neutral sentiment score of 0.00.
# The text with unique id 290 has a neutral sentiment score of 0.00.
# The text with unique id 291 has a positive sentiment score of 0.70.
# The text with unique id 292 has a neutral sentiment score of 0.00.
# The text with unique id 293 has a neutral sentiment score of 0.00.
# The text with unique id 294 has a positive sentiment score of 0.03.
# The text with unique id 295 has a positive sentiment score of 0.70.
# The text with unique id 296 has a positive sentiment score of 0.44.
# The text with unique id 297 has a negative sentiment score of -0.10.
# The text with unique id 298 has a positive sentiment score of 0.44.
# The text with unique id 299 has a neutral sentiment score of 0.00.
# The text with unique id 300 has a neutral sentiment score of 0.00.
# The text with unique id 301 has a positive sentiment score of 0.44.
# The text with unique id 302 has a neutral sentiment score of 0.00.
# The text with unique id 303 has a neutral sentiment score of 0.00.
# The text with unique id 304 has a neutral sentiment score of 0.00.
# The text with unique id 305 has a neutral sentiment score of 0.00.
# The text with unique id 306 has a neutral sentiment score of 0.00.
# The text with unique id 307 has a neutral sentiment score of 0.00.
# The text with unique id 308 has a neutral sentiment score of 0.00.
# The text with unique id 309 has a neutral sentiment score of 0.00.
# The text with unique id 310 has a neutral sentiment score of 0.00.
# The text with unique id 311 has a positive sentiment score of 0.44.
# The text with unique id 312 has a positive sentiment score of 0.57.
# The text with unique id 313 has a neutral sentiment score of 0.00.
# The text with unique id 314 has a neutral sentiment score of 0.00.
# The text with unique id 315 has a neutral sentiment score of 0.00.
# The text with unique id 316 has a neutral sentiment score of 0.00.
# The text with unique id 317 has a neutral sentiment score of 0.00.
# The text with unique id 318 has a positive sentiment score of 0.44.
# The text with unique id 319 has a neutral sentiment score of 0.00.
# The text with unique id 320 has a neutral sentiment score of 0.00.
# The text with unique id 321 has a neutral sentiment score of 0.00.
# The text with unique id 322 has a neutral sentiment score of 0.00.
# The text with unique id 323 has a neutral sentiment score of 0.00.
# The text with unique id 324 has a neutral sentiment score of 0.00.
# The text with unique id 325 has a neutral sentiment score of 0.00.
# The text with unique id 326 has a neutral sentiment score of 0.00.
# The text with unique id 327 has a neutral sentiment score of 0.00.
# The text with unique id 328 has a neutral sentiment score of 0.00.
# The text with unique id 329 has a neutral sentiment score of 0.00.
# The text with unique id 330 has a neutral sentiment score of 0.00.
# The text with unique id 331 has a neutral sentiment score of 0.00.
# The text with unique id 332 has a neutral sentiment score of 0.00.
# The text with unique id 333 has a neutral sentiment score of 0.00.
# The text with unique id 334 has a neutral sentiment score of 0.00.
# The text with unique id 335 has a neutral sentiment score of 0.00.
# The text with unique id 336 has a neutral sentiment score of 0.00.
# The text with unique id 337 has a neutral sentiment score of 0.00.
# The text with unique id 338 has a neutral sentiment score of 0.00.
# The text with unique id 339 has a neutral sentiment score of 0.00.
# The text with unique id 340 has a neutral sentiment score of 0.00.
# The text with unique id 341 has a neutral sentiment score of 0.00.
# The text with unique id 342 has a neutral sentiment score of 0.00.
# The text with unique id 343 has a neutral sentiment score of 0.00.
# The text with unique id 344 has a neutral sentiment score of 0.00.
# The text with unique id 345 has a neutral sentiment score of 0.00.
# The text with unique id 346 has a neutral sentiment score of 0.00.
# The text with unique id 347 has a neutral sentiment score of 0.00.
# The text with unique id 348 has a neutral sentiment score of 0.00.
# The text with unique id 349 has a positive sentiment score of 0.44.
# The text with unique id 350 has a neutral sentiment score of 0.00.
# The text with unique id 351 has a neutral sentiment score of 0.00.

# %%
#Create a new DataFrame with the sentiment scores for positive, negative and neutral texts
sentiment_df = pd.DataFrame({
'positive': grouped[grouped > 0],
'negative': grouped[grouped < 0],
'neutral': grouped[grouped == 0]
})

#Sort the DataFrame by the index (i.e., the unique identifier)
sentiment_df = sentiment_df.sort_index()

#Plot the sentiment scores as a stacked bar chart
fig, ax = plt.subplots(figsize=(10, 5))

ax.bar(sentiment_df.index, sentiment_df['positive'], color='green', label='Positive')
ax.bar(sentiment_df.index, sentiment_df['negative'], color='red', label='Negative')
ax.bar(sentiment_df.index, sentiment_df['neutral'], color='gray', label='Neutral', bottom=sentiment_df['negative'])

ax.set_xlabel('Unique Identifier')
ax.set_ylabel('Sentiment Score')
ax.set_title('Sentiment Analysis')
ax.legend()

plt.show()
