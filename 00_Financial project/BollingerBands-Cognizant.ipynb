# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\ashar\appdata\roaming\python\python39\site-packages (1.4.2)
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pytz>=2020.1 in c:\users\ashar\appdata\roaming\python\python39\site-packages (from pandas) (2022.1)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\ashar\anaconda3\envs\financialanalytics\lib\site-packages (from pandas) (1.24.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\ashar\appdata\roaming\python\python39\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\ashar\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
# !pip install yfinance 
# !pip install matplotlib 
# !pip install ta --upgrade
# Out:
# Requirement already satisfied: yfinance in c:\users\ashar\anaconda3\envs\financialanalytics\lib\site-packages (0.2.12)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\ashar\anaconda3\envs\financialanalytics\lib\site-packages (from yfinance) (1.24.1)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\ashar\appdata\roaming\python\python39\site-packages (from yfinance) (4.9.1)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\ashar\anaconda3\envs\financialanalytics\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: pytz>=2022.5 in c:\users\ashar\anaconda3\envs\financialanalytics\lib\site-packages (from yfinance) (2022.7.1)
# Requirement already satisfied: cryptography>=3.3.2 in c:\users\ashar\anaconda3\envs\financialanalytics\lib\site-packages (from yfinance) (38.0.4)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\ashar\anaconda3\envs\financialanalytics\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\ashar\appdata\roaming\python\python39\site-packages (from yfinance) (1.4.2)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\ashar\anaconda3\envs\financialanalytics\lib\site-packages (from yfinance) (2.3.5)
# Requirement already satisfied: requests>=2.26 in c:\users\ashar\appdata\roaming\python\python39\site-packages (from yfinance) (2.28.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\ashar\anaconda3\envs\financialanalytics\lib\site-packages (from yfinance) (4.11.1)
# Requirement already satisfied: html5lib>=1.1 in c:\users\ashar\anaconda3\envs\financialanalytics\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ashar\anaconda3\envs\financialanalytics\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.2.post1)
# Requirement already satisfied: cffi>=1.12 in c:\users\ashar\anaconda3\envs\financialanalytics\lib\site-packages (from cryptography>=3.3.2->yfinance) (1.15.1)
# Requirement already satisfied: six>=1.9 in c:\users\ashar\appdata\roaming\python\python39\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\ashar\anaconda3\envs\financialanalytics\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\ashar\appdata\roaming\python\python39\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ashar\appdata\roaming\python\python39\site-packages (from requests>=2.26->yfinance) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ashar\appdata\roaming\python\python39\site-packages (from requests>=2.26->yfinance) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ashar\appdata\roaming\python\python39\site-packages (from requests>=2.26->yfinance) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\ashar\appdata\roaming\python\python39\site-packages (from requests>=2.26->yfinance) (2.1.1)
# Requirement already satisfied: pycparser in c:\users\ashar\anaconda3\envs\financialanalytics\lib\site-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance) (2.21)
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: matplotlib in c:\users\ashar\appdata\roaming\python\python39\site-packages (3.5.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ashar\appdata\roaming\python\python39\site-packages (from matplotlib) (9.1.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ashar\appdata\roaming\python\python39\site-packages (from matplotlib) (4.33.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ashar\appdata\roaming\python\python39\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\ashar\appdata\roaming\python\python39\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\ashar\appdata\roaming\python\python39\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\ashar\appdata\roaming\python\python39\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ashar\appdata\roaming\python\python39\site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\ashar\anaconda3\envs\financialanalytics\lib\site-packages (from matplotlib) (1.24.1)
# Requirement already satisfied: six>=1.5 in c:\users\ashar\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting ta
#   Using cached ta-0.10.2.tar.gz (25 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy in c:\users\ashar\anaconda3\envs\financialanalytics\lib\site-packages (from ta) (1.24.1)
# Requirement already satisfied: pandas in c:\users\ashar\appdata\roaming\python\python39\site-packages (from ta) (1.4.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ashar\anaconda3\envs\financialanalytics\lib\site-packages (from pandas->ta) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\ashar\appdata\roaming\python\python39\site-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\ashar\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.8.1->pandas->ta) (1.16.0)
# Building wheels for collected packages: ta
#   Building wheel for ta (setup.py): started
#   Building wheel for ta (setup.py): finished with status 'done'
#   Created wheel for ta: filename=ta-0.10.2-py3-none-any.whl size=29088 sha256=a78b62d2d47312f193f4b25bd972147b3c677f3c3f48eecc1bde3bf7172b2400
#   Stored in directory: c:\users\ashar\appdata\local\pip\cache\wheels\4c\b6\d3\f919b6ed5638198dd32b8fbea60cee9d074d4825eea2c71db8
# Successfully built ta
# Installing collected packages: ta
# Successfully installed ta-0.10.2
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
import ta

# %%
plt.style.use("seaborn")
plt.rcparams["figure.figsize"] =[14,8]

# %%
df = yf.download("MSFT",start="2021-01-01", end = "2021-12-31")
df["Adj Close"].plot(title ="Microsoft Stock for 2021")
# Out:
# [*********************100%***********************]  1 of 1 completed
# <AxesSubplot:title={'center':'Microsoft Stock for 2021'}, xlabel='Date'>

# %%
ta_bbands = ta.volatility.BollingerBands(close =df["Adj Close"], window =20,window_dev=2)
ta_df = df.copy()
ta_df["bb_ma"]=ta_bbands.bollinger_mavg()


ta_df["bb_high"]=ta_bbands.bollinger_hband()
ta_df["bb_low"]=ta_bbands.bollinger_lband()

ta_df[["bb_low","bb_ma","bb_high"]].plot(title ="Bollinger bands (ta")
# Out:
# <AxesSubplot:title={'center':'Bollinger bands (ta'}, xlabel='Date'>
